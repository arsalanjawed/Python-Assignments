# %% [markdown]
# Q1

# %%
person= {
        "First_Name":"Arsalan",
        "Last_Name":"Jawed",
        "Age":"19",
        "City":"karachi"
    }

person.update({"Qualification" : "BSCS"})
print(person)
del person["Qualification"]
print(person)
# Out:
# {'First_Name': 'Arsalan', 'Last_Name': 'Jawed', 'Age': '19', 'City': 'karachi', 'Qualification': 'BSCS'}
# {'First_Name': 'Arsalan', 'Last_Name': 'Jawed', 'Age': '19', 'City': 'karachi'}

# %% [markdown]
# Q2

# %%
cities = {
    'Karachi': {
        'country': 'Pakistan',
        'population': 5741000,
        'Fact': 'It is the Sixth largest city in the world by city population'
        },
    'Mumbai': {
        'country': 'India',
        'population': 185064,
        'Fact': 'It is the Sixth largest city in the world by city population'
        },
    'Florence': {
        'country': 'Italy',
        'population': 1003285,
        'Fact': 'Florence is regarded as one of the fashion capitals of the world.'
        }
    }
for key, value in cities.items():
    print("The city name is : ",key,"\n",value)
    print("\n")
# Out:
# The city name is :  Karachi
#  {'country': 'Pakistan', 'population': 5741000, 'Fact': 'It is the Sixth largest city in the world by city population'}
#
#
# The city name is :  Mumbai
#  {'country': 'India', 'population': 185064, 'Fact': 'It is the Sixth largest city in the world by city population'}
#
#
# The city name is :  Florence
#  {'country': 'Italy', 'population': 1003285, 'Fact': 'Florence is regarded as one of the fashion capitals of the world.'}

# %% [markdown]
# Q3

# %%
tickets=int(input("How many tickets you want to buy?"))
cost=0
i=0
while(i<tickets):
    name=input("Enter your name : ")
    age=int(input("Enter your age : "))
    if age < 3:
        print("Ticket is free.")
    elif age>=3 and age <=12:
        print("Ticket is $10")
        cost+=10
    elif age > 12 :
        print("Ticket is $15")
        cost+=15
    else:
        print("Wrong input")
    i+=1

print("Your Total Cost is : ",cost)
# Out:
# How many tickets you want to buy?2
# Enter your name : Aj
# Enter your age : 15
# Ticket is $15
# Enter your name : Khan
# Enter your age : 10
# Ticket is $10
# Your Total Cost is :  25

# %% [markdown]
# Q4

# %%
def favourite_book(title):
    print("one of my favourite book is ",title)

book=input("What is your favourite book ? ")
favourite_book(book)
# Out:
# What is your favourite book ? Smarter way to learn python
# one of my favourite book is  Smarter way to learn python

# %% [markdown]
# Q5

# %%
import random

guessesTaken = 0

print('Hello! What is your name?')
myName = input()
number = random.randint(1, 30)

print('Well, ' + myName + ', I am thinking of a number between 1 and 30.')
while guessesTaken < 3:

    guess = int(input())
    guessesTaken = guessesTaken + 1
    if guess < number:
        print('Your guess is  less than my number.')
    if guess > number:
        print('Your guess is greater then my number')
    if guess == number:
        break
if guess == number:
    guessesTaken = str(guessesTaken)
    print('Good job, ' + myName + '! You guessed my number in ' + guessesTaken + ' guesses!')
if guess != number:
    number = str(number)
    print('Nope. The number I was thinking of was ' + number)
# Out:
# Hello! What is your name?
# Arsalan
# Well, Arsalan, I am thinking of a number between 1 and 30.
# 10
# Your guess is greater then my number
# 7
# Your guess is greater then my number
# 4
# Your guess is  less than my number.
# Nope. The number I was thinking of was 6
